# %%
import pandas as pd
import seaborn as sns
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in data set with first column (district name) set to index
df = pd.read_excel("completed_data.xlsx", index_col =0)

# %%
df.head()
# Out:
#                                                     District Code High Needs#  \
# District Name
# Abby Kelley Foster Charter Public (District)              4450000       1,005
# Abington                                                    10000       1,029
# Academy Of the Pacific Rim Charter Public (Dist...        4120000         332
# Acton-Boxborough                                          6000000       1,538
# Acushnet                                                    30000         415
#
#                                                     High Needs%  \
# District Name
# Abby Kelley Foster Charter Public (District)               70.7
# Abington                                                   47.3
# Academy Of the Pacific Rim Charter Public (Dist...         71.1
# Acton-Boxborough                                           29.6
# Acushnet                                                   42.7
#
#                                                    English Learners#  \
# ...

# %%
print(df.columns)
# Out:
# Index(['District Code', 'High Needs#', 'High Needs%', 'English Learners#',
#        'English Learners%', 'First Language Not English#',
#        'First Language Not English%', 'Low Income#', 'Low Income%',
#        'Students with Disabilities#.1', 'Students with Disabilities%.1',
#        'Overall Classification', 'Reason for Classification',
#        'Progress Toward Improvement Targets (%)', 'In-District Expenditures',
#        'Total In-district FTEs', 'In-District Expenditures per Pupil',
#        'Total Expenditures', 'Total Pupil FTEs',
#        'Total Expenditures per Pupil', '# in Cohort', '% Graduated',
#        '% Still in School', '% Non-Grad Completers', '% H.S. Equiv.',
#        '% Dropped Out', '% Permanently Excluded', 'Total # of Teachers (FTE)',
#        '% of Teachers Licensed', 'Student / Teacher Ratio',
#        'Percent of Experienced Teachers',
#        'Percent of Teachers without Waiver or Provisional License',
# ...

# %%
df.drop(['High Needs#', 'English Learners#', 'First Language Not English#', 'Low Income#', 'Students with Disabilities#.1', 'CleanedName', '# in Cohort', 'District Code'], axis = 1, inplace=True)

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 300)
df.head()
# Out:
#                                                     High Needs%  \
# District Name
# Abby Kelley Foster Charter Public (District)               70.7
# Abington                                                   47.3
# Academy Of the Pacific Rim Charter Public (Dist...         71.1
# Acton-Boxborough                                           29.6
# Acushnet                                                   42.7
#
#                                                     English Learners%  \
# District Name
# Abby Kelley Foster Charter Public (District)                     18.0
# Abington                                                         11.0
# Academy Of the Pacific Rim Charter Public (Dist...                9.4
# Acton-Boxborough                                                  6.2
# Acushnet                                                          0.6
#
#                                                     First Language Not English%  \
# District Name
# ...

# %%
# drop rows where graduation rate = NaN; these districts do not include high school grades and feed into other districts for grades 9-12
df.dropna(subset = ["% Graduated"], inplace = True)

# %%
df.isnull().sum()
# Out:
# High Needs%                                                   0
# English Learners%                                             0
# First Language Not English%                                   0
# Low Income%                                                   0
# Students with Disabilities%.1                                 0
# Overall Classification                                        1
# Reason for Classification                                     1
# Progress Toward Improvement Targets (%)                       9
# In-District Expenditures                                      1
# Total In-district FTEs                                        1
# In-District Expenditures per Pupil                            1
# Total Expenditures                                            1
# Total Pupil FTEs                                              1
# Total Expenditures per Pupil                                  1
# % Graduated                                                   0
# ...

# %%
df[df['Overall Classification'].isna()]
# Out:
#                High Needs%  English Learners%  First Language Not English%  \
# District Name
# State Totals          55.1               12.1                         25.0
#
#                Low Income%  Students with Disabilities%.1  \
# District Name
# State Totals          42.3                           19.4
#
#               Overall Classification Reason for Classification  \
# District Name
# State Totals                     NaN                       NaN
#
#                Progress Toward Improvement Targets (%)  \
# District Name
# State Totals                                       NaN
#
#                In-District Expenditures Total In-district FTEs  \
# District Name
# State Totals         $18,401,964,825.00              865,749.1
#
#               In-District Expenditures per Pupil        Total Expenditures  \
# District Name
# State Totals                          $21,255.54        $20,737,958,663.00
#
# ...

# %%
#drop "State Totals" row
df.drop(['State Totals'], axis = 0, inplace = True)

# %%
df.tail()
# Out:
#                High Needs%  English Learners%  First Language Not English%  \
# District Name
# Winchendon            63.5                1.7                          2.8
# Winchester            25.9                3.3                         20.3
# Winthrop              50.6                9.5                         21.8
# Woburn                53.6               10.8                         20.9
# Worcester             82.9               30.4                         58.4
#
#                Low Income%  Students with Disabilities%.1  \
# District Name
# Winchendon            55.5                           18.1
# Winchester             6.9                           15.9
# Winthrop              38.2                           16.1
# Woburn                38.7                           20.6
# Worcester             72.5                           21.2
#
#                                  Overall Classification  \
# District Name
# Winchendon     Not requiring assistance or intervention
# ...

# %%
# rename columns, Students with Disabilities%.1, High Needs%, English Learners%, First Language Not English%, Low Income%, Progress Toward Improvement Targets (%) and MEMBERS
df.rename(columns={'Students with Disabilities%.1': '% Students with Disabilities'}, inplace = True)
df.rename(columns={'High Needs%': '% High Needs'}, inplace = True)
df.rename(columns={'English Learners%': '% English Learners'}, inplace = True)
df.rename(columns={'Low Income%': '% Low Income'}, inplace = True)
df.rename(columns={'First Language Not English%': '% First Language Not English'}, inplace = True)
df.rename(columns={'Progress Toward Improvement Targets (%)': '% Progress Toward Improvement Targets'}, inplace = True)
df.rename(columns={'MEMBERS' : 'Members'}, inplace = True)
df.head()
# Out:
#                                                     % High Needs  \
# District Name
# Abby Kelley Foster Charter Public (District)                70.7
# Abington                                                    47.3
# Academy Of the Pacific Rim Charter Public (Dist...          71.1
# Acton-Boxborough                                            29.6
# Advanced Math and Science Academy Charter (Dist...          26.0
#
#                                                     % English Learners  \
# District Name
# Abby Kelley Foster Charter Public (District)                      18.0
# Abington                                                          11.0
# Academy Of the Pacific Rim Charter Public (Dist...                 9.4
# Acton-Boxborough                                                   6.2
# Advanced Math and Science Academy Charter (Dist...                 1.4
#
#                                                     % First Language Not English  \
# District Name
# ...

# %%
df['Student / Teacher Ratio'] = df['Student / Teacher Ratio'].str.replace(' to 1', '')

# %%
df.head()
# Out:
#                                                     % High Needs  \
# District Name
# Abby Kelley Foster Charter Public (District)                70.7
# Abington                                                    47.3
# Academy Of the Pacific Rim Charter Public (Dist...          71.1
# Acton-Boxborough                                            29.6
# Advanced Math and Science Academy Charter (Dist...          26.0
#
#                                                     % English Learners  \
# District Name
# Abby Kelley Foster Charter Public (District)                      18.0
# Abington                                                          11.0
# Academy Of the Pacific Rim Charter Public (Dist...                 9.4
# Acton-Boxborough                                                   6.2
# Advanced Math and Science Academy Charter (Dist...                 1.4
#
#                                                     % First Language Not English  \
# District Name
# ...

# %%
df.isnull().sum()
# Out:
# % High Needs                                                  0
# % English Learners                                            0
# % First Language Not English                                  0
# % Low Income                                                  0
# % Students with Disabilities                                  0
# Overall Classification                                        0
# Reason for Classification                                     0
# % Progress Toward Improvement Targets                         8
# In-District Expenditures                                      1
# Total In-district FTEs                                        1
# In-District Expenditures per Pupil                            1
# Total Expenditures                                            1
# Total Pupil FTEs                                              1
# Total Expenditures per Pupil                                  1
# % Graduated                                                   0
# ...

# %%
df[df['Population'].isna()]
# Out:
#                                                     % High Needs  \
# District Name
# Argosy Collegiate Charter School (District)                 85.0
# Assabet Valley Regional Vocational Technical                58.9
# Ayer Shirley School District                                45.5
# Baystate Academy Charter Public School (District)           88.8
# Blackstone Valley Regional Vocational Technical             25.0
# Blue Hills Regional Vocational Technical                    57.5
# Boston Green Academy Horace Mann Charter School...          88.2
# Bristol County Agricultural                                 41.3
# Bristol-Plymouth Regional Vocational Technical              40.8
# Brooke Charter School (District)                            72.0
# Cape Cod Regional Vocational Technical                      56.5
# City on a Hill Charter Public School (District)             87.4
# Collegiate Charter School of Lowell (District)              77.5
# ...

# %%
df[df['% Progress Toward Improvement Targets'].isna()]
# Out:
#                                                     % High Needs  \
# District Name
# Boston Day and Evening Academy Charter (District)           89.1
# Hatfield                                                    39.1
# Lowell Middlesex Academy Charter (District)                 88.0
# Ma Academy for Math and Science                              2.0
# Martha's Vineyard Charter Public School (District)          53.6
# Phoenix Academy Charter Public High School, Che...          95.1
# Phoenix Academy Public Charter High School, Law...          92.0
# Phoenix Academy Public Charter High School, Spr...          92.2
#
#                                                     % English Learners  \
# District Name
# Boston Day and Evening Academy Charter (District)                  8.4
# Hatfield                                                           0.3
# Lowell Middlesex Academy Charter (District)                        0.0
# ...

# %%
df[df['In-District Expenditures'].isna()]
# Out:
#                                  % High Needs  % English Learners  \
# District Name
# Ma Academy for Math and Science           2.0                 0.0
#
#                                  % First Language Not English  % Low Income  \
# District Name
# Ma Academy for Math and Science                           0.0           2.0
#
#                                  % Students with Disabilities  \
# District Name
# Ma Academy for Math and Science                           0.0
#
#                                 Overall Classification  \
# District Name
# Ma Academy for Math and Science      Insufficient data
#
#                                 Reason for Classification  \
# District Name
# Ma Academy for Math and Science         Insufficient data
#
#                                  % Progress Toward Improvement Targets  \
# District Name
# Ma Academy for Math and Science                                    NaN
#
#                                 In-District Expenditures  \
# ...

# %%
df[df['Total # of Teachers (FTE)'].isna()]
# Out:
#                                         % High Needs  % English Learners  \
# District Name
# Foxborough Regional Charter (District)          51.6                 6.9
#
#                                         % First Language Not English  \
# District Name
# Foxborough Regional Charter (District)                          17.1
#
#                                         % Low Income  \
# District Name
# Foxborough Regional Charter (District)          41.8
#
#                                         % Students with Disabilities  \
# District Name
# Foxborough Regional Charter (District)                           9.3
#
#                                                           Overall Classification  \
# District Name
# Foxborough Regional Charter (District)  Not requiring assistance or intervention
#
#                                                Reason for Classification  \
# District Name
# Foxborough Regional Charter (District)  Moderate progress toward targets
#
# ...
